# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.base import BaseEstimator
from sklearn.impute import SimpleImputer
# knn
from sklearn.neighbors import KNeighborsClassifier
# linear models
from sklearn.linear_model import LogisticRegression
# visualization
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Rectangle, FancyBboxPatch, FancyArrowPatch
import matplotlib.patches as mpatches

# %% [markdown]
# ## adding data

# %%
df = pd.read_csv('./bank.csv')
df
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 0       unknown    5   may      1042         1     -1         0  unknown
# 1       unknown    5   may      1467         1     -1         0  unknown
# 2       unknown    5   may      1389         1     -1         0  unknown
# 3       unknown    5   may       579         1     -1         0  unknown
# 4       unknown    5   may       673         2     -1         0  unknown
# ...         ...  ...   ...       ...       ...    ...       ...      ...
# 11157  cellular   20   apr       257         1     -1         0  unknown
# 11158   unknown   16   jun        83         4     -1         0  unknown
# 11159  cellular   19   aug       156         2     -1         0  unknown
# 11160  cellular    8   may         9         2    172         5  failure
# 11161  cellular    9   jul       628         1     -1         0  unknown
#
#       deposit
# 0         yes
# 1         yes
# 2         yes
# 3         yes
# 4         yes
# ...       ...
# 11157      no
# 11158      no
# 11159      no
# 11160      no
# 11161      no
#
# [11162 rows x 17 columns]

# %% [markdown]
# ## getting html report

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title="Profiling Report")
profile.to_file("report.html")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 17/17 [00:00<00:00, 46.03it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## splitting

# %%
y = df['deposit']
X = df.drop('deposit', axis=1)

random_state = 999
test_size = 0.2

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

# %%
NUMERICAL = {'age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'}
CATEGORICAL = set(X.columns) - NUMERICAL
CATEGORICAL, NUMERICAL = list(CATEGORICAL), list(NUMERICAL)

# %% [markdown]
# ## Preprocessing

# %%
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),  #we dont have missing value but for sure :)
    ('scaler', MinMaxScaler())                 
])

# %% [markdown]
# This pipeline fills missing categorical values with the most frequent category, then applies One-Hot encoding to produce binary indicator vectors for each category.
#
#
# normalization Formula:  $x_{scaled} = \frac{x - x_{min}}{x_{max} - x_{min}}$

# %%
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent', fill_value='missing')),  #we dont have missing value but for sure :)
    ('onehot', OneHotEncoder(handle_unknown='ignore'))                    
])

# %% [markdown]
# This pipeline fills missing categorical values with the most frequent category, then applies One-Hot encoding to produce binary indicator vectors for each category.

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, NUMERICAL),
        ('cat', categorical_transformer, CATEGORICAL)
    ]
)

# %% [markdown]
# The `ColumnTransformer` splits the dataset’s features into two parallel paths—numerical and categorical—and applies different preprocessing pipelines to each group.
#
# *   **Numerical columns** are processed by `numerical_transformer` (mean imputation + scaling).
# *   **Categorical columns** are processed by `categorical_transformer` (most‑frequent imputation + one‑hot encoding).
#
# After these transformations, the outputs from both paths are concatenated into a single unified feature matrix for model training.

# %% [markdown]
# ## requiered functions for handmade Dtree (entropy & information gain)

# %% [markdown]
# Entropy = $H(S) = - \sum_{i=1}^{k} p_i \log_2(p_i)$

# %% [markdown]
# Information Gain = $IG(S, A) = H(S) - \frac{|S_L|}{|S|}H(S_L) - \frac{|S_R|}{|S|}H(S_R)$

# %%
import numpy as np

def entropy(y):
    """Shannon entropy H(S) = -Σ p_i log2(p_i)."""
    if len(y) == 0:
        return 0
    _, counts = np.unique(y, return_counts=True)
    p = counts / len(y)
    p = p[p > 0]  # avoid log2(0)
    return -np.sum(p * np.log2(p))


def information_gain(y, y_left, y_right):
    """Information Gain = H(parent) - weighted avg entropy of children."""
    n = len(y)
    if n == 0:
        return 0
    H_parent = entropy(y)
    H_left = entropy(y_left)
    H_right = entropy(y_right)
    w_left = len(y_left) / n
    w_right = len(y_right) / n
    return H_parent - (w_left * H_left + w_right * H_right)

# %% [markdown]
# ## handmade decision tree

# %%
from sklearn.base import BaseEstimator, ClassifierMixin

class HandmadeDecisionTree(BaseEstimator, ClassifierMixin):
    def __init__(self, max_depth=None, min_samples_split=2, min_samples_leaf=1, random_state=None):
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split
        self.min_samples_leaf = min_samples_leaf
        self.random_state = random_state
        self.tree = None
        self.classes_ = None

    def _find_best_split(self, X, y):
        best_gain = -1
        best_feature = None
        best_threshold = None
        n_features = X.shape[1]
        if self.random_state is not None:
            np.random.seed(self.random_state)
            feature_indices = np.random.permutation(n_features)
        else:
            feature_indices = range(n_features)

        for feature_idx in feature_indices:
            feature_values = X[:, feature_idx]
            unique_values = np.unique(feature_values)
            for threshold in unique_values:
                left_mask = feature_values <= threshold
                right_mask = ~left_mask
                if np.sum(left_mask) < self.min_samples_leaf or np.sum(right_mask) < self.min_samples_leaf:
                    continue
                y_left, y_right = y[left_mask], y[right_mask]
                gain = information_gain(y, y_left, y_right)  # ✅ استفاده از تابع بالا
                if gain > best_gain:
                    best_gain, best_feature, best_threshold = gain, feature_idx, threshold
        return best_feature, best_threshold, best_gain

    def _build_tree(self, X, y, depth=0):
        n_samples, n_classes = len(y), len(np.unique(y))
        if (self.max_depth is not None and depth >= self.max_depth) or n_samples < self.min_samples_split or n_classes == 1:
            class_counts = np.bincount(y, minlength=len(self.classes_))
            return {'is_leaf': True, 'class': np.argmax(class_counts), 'samples': n_samples}

        best_feature, best_threshold, best_gain = self._find_best_split(X, y)
        if best_feature is None or best_gain <= 0:
            class_counts = np.bincount(y, minlength=len(self.classes_))
            return {'is_leaf': True, 'class': np.argmax(class_counts), 'samples': n_samples}

        left_mask = X[:, best_feature] <= best_threshold
        right_mask = ~left_mask
        left_tree = self._build_tree(X[left_mask], y[left_mask], depth + 1)
        right_tree = self._build_tree(X[right_mask], y[right_mask], depth + 1)

        return {
            'is_leaf': False,
            'feature': best_feature,
            'threshold': best_threshold,
            'gain': best_gain,
            'left': left_tree,
            'right': right_tree,
            'samples': n_samples
        }

    def _predict_sample(self, sample, node):
        if node['is_leaf']:
            return node['class']
        if sample[node['feature']] <= node['threshold']:
            return self._predict_sample(sample, node['left'])
        else:
            return self._predict_sample(sample, node['right'])

    def fit(self, X, y):
        X = np.array(X)
        y = np.array(y)
        self.classes_ = np.unique(y)
        y_encoded = np.searchsorted(self.classes_, y)
        self.tree = self._build_tree(X, y_encoded)
        return self

    def predict(self, X):
        if self.tree is None:
            raise ValueError("Tree not trained yet. Call fit() first.")
        X = np.array(X)
        preds = [self.classes_[self._predict_sample(sample, self.tree)] for sample in X]
        return np.array(preds)

    def get_params(self, deep=True):
        return {
            "max_depth": self.max_depth,
            "min_samples_split": self.min_samples_split,
            "min_samples_leaf": self.min_samples_leaf,
            "random_state": self.random_state,
        }

    def set_params(self, **params):
        for k, v in params.items():
            setattr(self, k, v)
        return self

# %%
handmade_dt_model = HandmadeDecisionTree(max_depth=10, min_samples_split=5, random_state=random_state)

handmade_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', handmade_dt_model)
])

handmade_pipeline.fit(X_train, y_train)
y_pred_handmade = handmade_pipeline.predict(X_test)

print("Handmade Decision Tree Results:")
print(classification_report(y_test, y_pred_handmade, digits=4))
# Out:
# Handmade Decision Tree Results:
#               precision    recall  f1-score   support
#
#           no     0.8736    0.7946    0.8322      1183
#          yes     0.7900    0.8705    0.8283      1050
#
#     accuracy                         0.8303      2233
#    macro avg     0.8318    0.8325    0.8303      2233
# weighted avg     0.8343    0.8303    0.8304      2233

# %% [markdown]
# ## Decision Tree Structure Visualization

# %%
def print_tree(node, feature_names, depth=0):
    prefix = "│   " * depth
    if node["is_leaf"]:
        print(f"{prefix}└── Leaf → class = {node['class']}  (samples = {node['samples']})")
    else:
        feature = feature_names[node["feature"]]
        threshold = node["threshold"]
        gain = node["gain"]

        if isinstance(threshold, (float, int)):
            threshold_str = f"{threshold:.4f}"
        else:
            threshold_str = str(threshold)

        if isinstance(gain, (float, int)):
            gain_str = f"{gain:.4f}"
        else:
            gain_str = str(gain)

        print(f"{prefix}├── if {feature} <= {threshold_str}  (Gain = {gain_str})")
        print_tree(node["left"], feature_names, depth + 1)
        print(f"{prefix}└── else  # {feature} > {threshold_str}")
        print_tree(node["right"], feature_names, depth + 1)

# %%
handmade_dt_model.fit(X_train, y_train)
print("Decision Tree Structure:")
print_tree(handmade_dt_model.tree, feature_names=X_train.columns.tolist())
# Out:
# Decision Tree Structure:
# ├── if duration <= 383.0000  (Gain = 0.1460)
# │   ├── if contact <= telephone  (Gain = 0.0930)
# │   │   ├── if duration <= 129.0000  (Gain = 0.1086)
# │   │   │   ├── if duration <= 77.0000  (Gain = 0.0601)
# │   │   │   │   ├── if duration <= 62.0000  (Gain = 0.0231)
# │   │   │   │   │   ├── if age <= 23.0000  (Gain = 0.0109)
# │   │   │   │   │   │   └── Leaf → class = 0  (samples = 3)
# │   │   │   │   │   └── else  # age > 23.0000
# │   │   │   │   │   │   ├── if day <= 2.0000  (Gain = 0.0107)
# │   │   │   │   │   │   │   ├── if marital <= married  (Gain = 0.7219)
# │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 4)
# │   │   │   │   │   │   │   └── else  # marital > married
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 1)
# │   │   │   │   │   │   └── else  # day > 2.0000
# │   │   │   │   │   │   │   ├── if contact <= cellular  (Gain = 0.0056)
# │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 340)
# │   │   │   │   │   │   │   └── else  # contact > cellular
# │   │   │   │   │   │   │   │   ├── if day <= 10.0000  (Gain = 0.0271)
# │   │   │   │   │   │   │   │   │   ├── if day <= 9.0000  (Gain = 0.3095)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 17)
# │   │   │   │   │   │   │   │   │   └── else  # day > 9.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 1)
# │   │   │   │   │   │   │   │   └── else  # day > 10.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 64)
# │   │   │   │   └── else  # duration > 62.0000
# │   │   │   │   │   ├── if education <= secondary  (Gain = 0.0278)
# │   │   │   │   │   │   ├── if duration <= 63.0000  (Gain = 0.1036)
# │   │   │   │   │   │   │   ├── if previous <= 2.0000  (Gain = 0.4581)
# │   │   │   │   │   │   │   │   ├── if job <= admin.  (Gain = 0.5917)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 1)
# │   │   │   │   │   │   │   │   └── else  # job > admin.
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 6)
# │   │   │   │   │   │   │   └── else  # previous > 2.0000
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 2)
# │   │   │   │   │   │   └── else  # duration > 63.0000
# │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 104)
# │   │   │   │   │   └── else  # education > secondary
# │   │   │   │   │   │   ├── if campaign <= 3.0000  (Gain = 0.0519)
# │   │   │   │   │   │   │   ├── if month <= mar  (Gain = 0.0697)
# │   │   │   │   │   │   │   │   ├── if pdays <= 5.0000  (Gain = 0.0908)
# │   │   │   │   │   │   │   │   │   ├── if day <= 26.0000  (Gain = 0.0704)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 30)
# │   │   │   │   │   │   │   │   │   └── else  # day > 26.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 8)
# │   │   │   │   │   │   │   │   └── else  # pdays > 5.0000
# │   │   │   │   │   │   │   │   │   ├── if pdays <= 293.0000  (Gain = 0.9183)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 4)
# │   │   │   │   │   │   │   │   │   └── else  # pdays > 293.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 2)
# │   │   │   │   │   │   │   └── else  # month > mar
# │   │   │   │   │   │   │   │   ├── if balance <= 7687.0000  (Gain = 0.2164)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 28)
# │   │   │   │   │   │   │   │   └── else  # balance > 7687.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 1)
# │   │   │   │   │   │   └── else  # campaign > 3.0000
# │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 22)
# │   │   │   └── else  # duration > 77.0000
# │   │   │   │   ├── if month <= nov  (Gain = 0.0363)
# │   │   │   │   │   ├── if age <= 26.0000  (Gain = 0.0402)
# │   │   │   │   │   │   ├── if housing <= no  (Gain = 0.1662)
# │   │   │   │   │   │   │   ├── if day <= 4.0000  (Gain = 0.1503)
# │   │   │   │   │   │   │   │   ├── if balance <= 486.0000  (Gain = 0.4696)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 4)
# │   │   │   │   │   │   │   │   └── else  # balance > 486.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 3)
# │   │   │   │   │   │   │   └── else  # day > 4.0000
# │   │   │   │   │   │   │   │   ├── if poutcome <= other  (Gain = 0.2046)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 4)
# │   │   │   │   │   │   │   │   └── else  # poutcome > other
# │   │   │   │   │   │   │   │   │   ├── if loan <= no  (Gain = 0.1623)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 24)
# │   │   │   │   │   │   │   │   │   └── else  # loan > no
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 1)
# │   │   │   │   │   │   └── else  # housing > no
# │   │   │   │   │   │   │   ├── if duration <= 113.0000  (Gain = 0.5436)
# │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 7)
# │   │   │   │   │   │   │   └── else  # duration > 113.0000
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 1)
# │   │   │   │   │   └── else  # age > 26.0000
# │   │   │   │   │   │   ├── if day <= 27.0000  (Gain = 0.0295)
# │   │   │   │   │   │   │   ├── if month <= mar  (Gain = 0.0320)
# │   │   │   │   │   │   │   │   ├── if month <= jul  (Gain = 0.0994)
# │   │   │   │   │   │   │   │   │   ├── if month <= feb  (Gain = 0.0330)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 300)
# │   │   │   │   │   │   │   │   │   └── else  # month > feb
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 97)
# │   │   │   │   │   │   │   │   └── else  # month > jul
# │   │   │   │   │   │   │   │   │   ├── if duration <= 84.0000  (Gain = 0.0864)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 8)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 84.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 45)
# │   │   │   │   │   │   │   └── else  # month > mar
# │   │   │   │   │   │   │   │   ├── if balance <= 459.0000  (Gain = 0.0612)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 84)
# │   │   │   │   │   │   │   │   └── else  # balance > 459.0000
# │   │   │   │   │   │   │   │   │   ├── if day <= 22.0000  (Gain = 0.0877)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 86)
# │   │   │   │   │   │   │   │   │   └── else  # day > 22.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 6)
# │   │   │   │   │   │   └── else  # day > 27.0000
# │   │   │   │   │   │   │   ├── if month <= jun  (Gain = 0.0525)
# │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 99)
# │   │   │   │   │   │   │   └── else  # month > jun
# │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 3)
# │   │   │   │   └── else  # month > nov
# │   │   │   │   │   ├── if balance <= 55.0000  (Gain = 0.2125)
# │   │   │   │   │   │   └── Leaf → class = 0  (samples = 6)
# │   │   │   │   │   └── else  # balance > 55.0000
# │   │   │   │   │   │   ├── if duration <= 98.0000  (Gain = 0.1543)
# │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 11)
# │   │   │   │   │   │   └── else  # duration > 98.0000
# │   │   │   │   │   │   │   ├── if day <= 26.0000  (Gain = 0.1989)
# │   │   │   │   │   │   │   │   ├── if age <= 26.0000  (Gain = 0.1520)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 3)
# │   │   │   │   │   │   │   │   └── else  # age > 26.0000
# │   │   │   │   │   │   │   │   │   ├── if month <= oct  (Gain = 0.2056)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 11)
# │   │   │   │   │   │   │   │   │   └── else  # month > oct
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 8)
# │   │   │   │   │   │   │   └── else  # day > 26.0000
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 7)
# │   │   └── else  # duration > 129.0000
# │   │   │   ├── if pdays <= 8.0000  (Gain = 0.0708)
# │   │   │   │   ├── if housing <= no  (Gain = 0.0525)
# │   │   │   │   │   ├── if month <= jul  (Gain = 0.0598)
# │   │   │   │   │   │   ├── if month <= apr  (Gain = 0.0769)
# │   │   │   │   │   │   │   ├── if duration <= 285.0000  (Gain = 0.0307)
# │   │   │   │   │   │   │   │   ├── if day <= 29.0000  (Gain = 0.0496)
# │   │   │   │   │   │   │   │   │   ├── if duration <= 158.0000  (Gain = 0.0800)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 18)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 158.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 66)
# │   │   │   │   │   │   │   │   └── else  # day > 29.0000
# │   │   │   │   │   │   │   │   │   ├── if duration <= 193.0000  (Gain = 0.3483)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 6)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 193.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 16)
# │   │   │   │   │   │   │   └── else  # duration > 285.0000
# │   │   │   │   │   │   │   │   ├── if duration <= 334.0000  (Gain = 0.0927)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 16)
# │   │   │   │   │   │   │   │   └── else  # duration > 334.0000
# │   │   │   │   │   │   │   │   │   ├── if duration <= 342.0000  (Gain = 0.6500)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 2)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 342.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 10)
# │   │   │   │   │   │   └── else  # month > apr
# │   │   │   │   │   │   │   ├── if balance <= 291.0000  (Gain = 0.0641)
# │   │   │   │   │   │   │   │   ├── if age <= 25.0000  (Gain = 0.0541)
# │   │   │   │   │   │   │   │   │   ├── if duration <= 229.0000  (Gain = 0.4336)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 8)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 229.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 3)
# │   │   │   │   │   │   │   │   └── else  # age > 25.0000
# │   │   │   │   │   │   │   │   │   ├── if duration <= 329.0000  (Gain = 0.0516)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 264)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 329.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 41)
# │   │   │   │   │   │   │   └── else  # balance > 291.0000
# │   │   │   │   │   │   │   │   ├── if duration <= 203.0000  (Gain = 0.0567)
# │   │   │   │   │   │   │   │   │   ├── if job <= blue-collar  (Gain = 0.0435)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 37)
# │   │   │   │   │   │   │   │   │   └── else  # job > blue-collar
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 145)
# │   │   │   │   │   │   │   │   └── else  # duration > 203.0000
# │   │   │   │   │   │   │   │   │   ├── if age <= 60.0000  (Gain = 0.0958)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 225)
# │   │   │   │   │   │   │   │   │   └── else  # age > 60.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 34)
# │   │   │   │   │   └── else  # month > jul
# │   │   │   │   │   │   ├── if month <= mar  (Gain = 0.0466)
# │   │   │   │   │   │   │   ├── if duration <= 161.0000  (Gain = 0.0397)
# │   │   │   │   │   │   │   │   ├── if balance <= 336.0000  (Gain = 0.1928)
# │   │   │   │   │   │   │   │   │   ├── if job <= housemaid  (Gain = 0.3113)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 4)
# │   │   │   │   │   │   │   │   │   └── else  # job > housemaid
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 4)
# │   │   │   │   │   │   │   │   └── else  # balance > 336.0000
# │   │   │   │   │   │   │   │   │   ├── if month <= jun  (Gain = 0.2365)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 10)
# │   │   │   │   │   │   │   │   │   └── else  # month > jun
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 10)
# │   │   │   │   │   │   │   └── else  # duration > 161.0000
# │   │   │   │   │   │   │   │   ├── if day <= 2.0000  (Gain = 0.0455)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 31)
# │   │   │   │   │   │   │   │   └── else  # day > 2.0000
# │   │   │   │   │   │   │   │   │   ├── if age <= 30.0000  (Gain = 0.0351)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 35)
# │   │   │   │   │   │   │   │   │   └── else  # age > 30.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 68)
# │   │   │   │   │   │   └── else  # month > mar
# │   │   │   │   │   │   │   ├── if month <= nov  (Gain = 0.1017)
# │   │   │   │   │   │   │   │   ├── if day <= 16.0000  (Gain = 0.0773)
# │   │   │   │   │   │   │   │   │   ├── if month <= may  (Gain = 0.1858)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 29)
# │   │   │   │   │   │   │   │   │   └── else  # month > may
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 21)
# │   │   │   │   │   │   │   │   └── else  # day > 16.0000
# │   │   │   │   │   │   │   │   │   ├── if month <= may  (Gain = 0.2236)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 38)
# │   │   │   │   │   │   │   │   │   └── else  # month > may
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 70)
# │   │   │   │   │   │   │   └── else  # month > nov
# │   │   │   │   │   │   │   │   ├── if duration <= 376.0000  (Gain = 0.0453)
# │   │   │   │   │   │   │   │   │   ├── if age <= 74.0000  (Gain = 0.0388)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 100)
# │   │   │   │   │   │   │   │   │   └── else  # age > 74.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 11)
# │   │   │   │   │   │   │   │   └── else  # duration > 376.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 2)
# │   │   │   │   └── else  # housing > no
# │   │   │   │   │   ├── if month <= nov  (Gain = 0.0438)
# │   │   │   │   │   │   ├── if day <= 4.0000  (Gain = 0.0395)
# │   │   │   │   │   │   │   ├── if month <= feb  (Gain = 0.1826)
# │   │   │   │   │   │   │   │   ├── if education <= primary  (Gain = 0.1583)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 3)
# │   │   │   │   │   │   │   │   └── else  # education > primary
# │   │   │   │   │   │   │   │   │   ├── if month <= apr  (Gain = 0.0701)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 4)
# │   │   │   │   │   │   │   │   │   └── else  # month > apr
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 25)
# │   │   │   │   │   │   │   └── else  # month > feb
# │   │   │   │   │   │   │   │   ├── if age <= 36.0000  (Gain = 0.2455)
# │   │   │   │   │   │   │   │   │   ├── if duration <= 275.0000  (Gain = 0.4200)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 6)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 275.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 4)
# │   │   │   │   │   │   │   │   └── else  # age > 36.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 14)
# │   │   │   │   │   │   └── else  # day > 4.0000
# │   │   │   │   │   │   │   ├── if duration <= 252.0000  (Gain = 0.0225)
# │   │   │   │   │   │   │   │   ├── if age <= 57.0000  (Gain = 0.0308)
# │   │   │   │   │   │   │   │   │   ├── if campaign <= 4.0000  (Gain = 0.0187)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 325)
# │   │   │   │   │   │   │   │   │   └── else  # campaign > 4.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 42)
# │   │   │   │   │   │   │   │   └── else  # age > 57.0000
# │   │   │   │   │   │   │   │   │   ├── if age <= 60.0000  (Gain = 0.2129)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 12)
# │   │   │   │   │   │   │   │   │   └── else  # age > 60.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 3)
# │   │   │   │   │   │   │   └── else  # duration > 252.0000
# │   │   │   │   │   │   │   │   ├── if duration <= 380.0000  (Gain = 0.0331)
# │   │   │   │   │   │   │   │   │   ├── if education <= primary  (Gain = 0.0241)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 24)
# │   │   │   │   │   │   │   │   │   └── else  # education > primary
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 214)
# │   │   │   │   │   │   │   │   └── else  # duration > 380.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 4)
# │   │   │   │   │   └── else  # month > nov
# │   │   │   │   │   │   ├── if age <= 35.0000  (Gain = 0.1740)
# │   │   │   │   │   │   │   ├── if duration <= 245.0000  (Gain = 0.2813)
# │   │   │   │   │   │   │   │   ├── if job <= blue-collar  (Gain = 0.4591)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 2)
# │   │   │   │   │   │   │   │   └── else  # job > blue-collar
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 4)
# │   │   │   │   │   │   │   └── else  # duration > 245.0000
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 4)
# │   │   │   │   │   │   └── else  # age > 35.0000
# │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 12)
# │   │   │   └── else  # pdays > 8.0000
# │   │   │   │   ├── if poutcome <= other  (Gain = 0.1580)
# │   │   │   │   │   ├── if housing <= no  (Gain = 0.1092)
# │   │   │   │   │   │   ├── if balance <= 91.0000  (Gain = 0.0464)
# │   │   │   │   │   │   │   ├── if day <= 24.0000  (Gain = 0.1437)
# │   │   │   │   │   │   │   │   ├── if pdays <= 358.0000  (Gain = 0.1724)
# │   │   │   │   │   │   │   │   │   ├── if education <= secondary  (Gain = 0.1694)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 17)
# │   │   │   │   │   │   │   │   │   └── else  # education > secondary
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 13)
# │   │   │   │   │   │   │   │   └── else  # pdays > 358.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 3)
# │   │   │   │   │   │   │   └── else  # day > 24.0000
# │   │   │   │   │   │   │   │   ├── if age <= 32.0000  (Gain = 0.2971)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 4)
# │   │   │   │   │   │   │   │   └── else  # age > 32.0000
# │   │   │   │   │   │   │   │   │   ├── if duration <= 154.0000  (Gain = 0.3912)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 1)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 154.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 12)
# │   │   │   │   │   │   └── else  # balance > 91.0000
# │   │   │   │   │   │   │   ├── if age <= 27.0000  (Gain = 0.0276)
# │   │   │   │   │   │   │   │   ├── if age <= 20.0000  (Gain = 0.1326)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 2)
# │   │   │   │   │   │   │   │   └── else  # age > 20.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 32)
# │   │   │   │   │   │   │   └── else  # age > 27.0000
# │   │   │   │   │   │   │   │   ├── if poutcome <= failure  (Gain = 0.0143)
# │   │   │   │   │   │   │   │   │   ├── if duration <= 214.0000  (Gain = 0.0231)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 70)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 214.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 101)
# │   │   │   │   │   │   │   │   └── else  # poutcome > failure
# │   │   │   │   │   │   │   │   │   ├── if age <= 44.0000  (Gain = 0.0880)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 51)
# │   │   │   │   │   │   │   │   │   └── else  # age > 44.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 23)
# │   │   │   │   │   └── else  # housing > no
# │   │   │   │   │   │   ├── if month <= mar  (Gain = 0.0795)
# │   │   │   │   │   │   │   ├── if month <= apr  (Gain = 0.1047)
# │   │   │   │   │   │   │   │   ├── if pdays <= 305.0000  (Gain = 0.0926)
# │   │   │   │   │   │   │   │   │   ├── if marital <= divorced  (Gain = 0.0788)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 2)
# │   │   │   │   │   │   │   │   │   └── else  # marital > divorced
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 31)
# │   │   │   │   │   │   │   │   └── else  # pdays > 305.0000
# │   │   │   │   │   │   │   │   │   ├── if pdays <= 344.0000  (Gain = 0.2789)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 25)
# │   │   │   │   │   │   │   │   │   └── else  # pdays > 344.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 2)
# │   │   │   │   │   │   │   └── else  # month > apr
# │   │   │   │   │   │   │   │   ├── if pdays <= 271.0000  (Gain = 0.1205)
# │   │   │   │   │   │   │   │   │   ├── if pdays <= 183.0000  (Gain = 0.2538)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 40)
# │   │   │   │   │   │   │   │   │   └── else  # pdays > 183.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 32)
# │   │   │   │   │   │   │   │   └── else  # pdays > 271.0000
# │   │   │   │   │   │   │   │   │   ├── if balance <= 179.0000  (Gain = 0.1623)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 2)
# │   │   │   │   │   │   │   │   │   └── else  # balance > 179.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 23)
# │   │   │   │   │   │   └── else  # month > mar
# │   │   │   │   │   │   │   ├── if day <= 21.0000  (Gain = 0.1303)
# │   │   │   │   │   │   │   │   ├── if month <= nov  (Gain = 0.0757)
# │   │   │   │   │   │   │   │   │   ├── if duration <= 259.0000  (Gain = 0.0583)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 90)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 259.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 52)
# │   │   │   │   │   │   │   │   └── else  # month > nov
# │   │   │   │   │   │   │   │   │   ├── if duration <= 139.0000  (Gain = 0.3210)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 3)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 139.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 11)
# │   │   │   │   │   │   │   └── else  # day > 21.0000
# │   │   │   │   │   │   │   │   ├── if age <= 33.0000  (Gain = 0.2248)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 8)
# │   │   │   │   │   │   │   │   └── else  # age > 33.0000
# │   │   │   │   │   │   │   │   │   ├── if campaign <= 2.0000  (Gain = 0.3219)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 8)
# │   │   │   │   │   │   │   │   │   └── else  # campaign > 2.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 2)
# │   │   │   │   └── else  # poutcome > other
# │   │   │   │   │   ├── if campaign <= 3.0000  (Gain = 0.0099)
# │   │   │   │   │   │   ├── if previous <= 14.0000  (Gain = 0.0090)
# │   │   │   │   │   │   │   ├── if duration <= 159.0000  (Gain = 0.0078)
# │   │   │   │   │   │   │   │   ├── if housing <= no  (Gain = 0.0560)
# │   │   │   │   │   │   │   │   │   ├── if duration <= 157.0000  (Gain = 0.0851)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 33)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 157.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 3)
# │   │   │   │   │   │   │   │   └── else  # housing > no
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 12)
# │   │   │   │   │   │   │   └── else  # duration > 159.0000
# │   │   │   │   │   │   │   │   ├── if previous <= 1.0000  (Gain = 0.0105)
# │   │   │   │   │   │   │   │   │   ├── if pdays <= 82.0000  (Gain = 0.0313)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 8)
# │   │   │   │   │   │   │   │   │   └── else  # pdays > 82.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 124)
# │   │   │   │   │   │   │   │   └── else  # previous > 1.0000
# │   │   │   │   │   │   │   │   │   ├── if job <= admin.  (Gain = 0.0123)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 46)
# │   │   │   │   │   │   │   │   │   └── else  # job > admin.
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 262)
# │   │   │   │   │   │   └── else  # previous > 14.0000
# │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 1)
# │   │   │   │   │   └── else  # campaign > 3.0000
# │   │   │   │   │   │   ├── if month <= jan  (Gain = 0.1986)
# │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 15)
# │   │   │   │   │   │   └── else  # month > jan
# │   │   │   │   │   │   │   ├── if month <= may  (Gain = 0.3655)
# │   │   │   │   │   │   │   │   ├── if previous <= 2.0000  (Gain = 0.4200)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 4)
# │   │   │   │   │   │   │   │   └── else  # previous > 2.0000
# │   │   │   │   │   │   │   │   │   ├── if balance <= 294.0000  (Gain = 0.9183)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 2)
# │   │   │   │   │   │   │   │   │   └── else  # balance > 294.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 4)
# │   │   │   │   │   │   │   └── else  # month > may
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 7)
# │   └── else  # contact > telephone
# │   │   ├── if month <= may  (Gain = 0.0655)
# │   │   │   ├── if month <= jan  (Gain = 0.0328)
# │   │   │   │   ├── if balance <= 432.0000  (Gain = 0.2857)
# │   │   │   │   │   ├── if job <= management  (Gain = 0.4764)
# │   │   │   │   │   │   ├── if job <= admin.  (Gain = 0.3060)
# │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 1)
# │   │   │   │   │   │   └── else  # job > admin.
# │   │   │   │   │   │   │   ├── if marital <= married  (Gain = 0.1909)
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 3)
# │   │   │   │   │   │   │   └── else  # marital > married
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 3)
# │   │   │   │   │   └── else  # job > management
# │   │   │   │   │   │   └── Leaf → class = 0  (samples = 5)
# │   │   │   │   └── else  # balance > 432.0000
# │   │   │   │   │   └── Leaf → class = 1  (samples = 5)
# │   │   │   └── else  # month > jan
# │   │   │   │   ├── if pdays <= -1.0000  (Gain = 0.0124)
# │   │   │   │   │   ├── if duration <= 365.0000  (Gain = 0.0079)
# │   │   │   │   │   │   ├── if month <= mar  (Gain = 0.0036)
# │   │   │   │   │   │   │   ├── if month <= jun  (Gain = 0.0133)
# │   │   │   │   │   │   │   │   ├── if day <= 17.0000  (Gain = 0.0093)
# │   │   │   │   │   │   │   │   │   ├── if age <= 27.0000  (Gain = 0.0125)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 12)
# │   │   │   │   │   │   │   │   │   └── else  # age > 27.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 284)
# │   │   │   │   │   │   │   │   └── else  # day > 17.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 147)
# │   │   │   │   │   │   │   └── else  # month > jun
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 1)
# │   │   │   │   │   │   └── else  # month > mar
# │   │   │   │   │   │   │   ├── if age <= 33.0000  (Gain = 0.0067)
# │   │   │   │   │   │   │   │   ├── if education <= tertiary  (Gain = 0.0128)
# │   │   │   │   │   │   │   │   │   ├── if day <= 29.0000  (Gain = 0.0116)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 219)
# │   │   │   │   │   │   │   │   │   └── else  # day > 29.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 10)
# │   │   │   │   │   │   │   │   └── else  # education > tertiary
# │   │   │   │   │   │   │   │   │   ├── if day <= 21.0000  (Gain = 0.7219)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 4)
# │   │   │   │   │   │   │   │   │   └── else  # day > 21.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 1)
# │   │   │   │   │   │   │   └── else  # age > 33.0000
# │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 534)
# │   │   │   │   │   └── else  # duration > 365.0000
# │   │   │   │   │   │   ├── if month <= jun  (Gain = 0.3029)
# │   │   │   │   │   │   │   ├── if duration <= 371.0000  (Gain = 0.3113)
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 2)
# │   │   │   │   │   │   │   └── else  # duration > 371.0000
# │   │   │   │   │   │   │   │   ├── if duration <= 380.0000  (Gain = 0.9183)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 4)
# │   │   │   │   │   │   │   │   └── else  # duration > 380.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 2)
# │   │   │   │   │   │   └── else  # month > jun
# │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 21)
# │   │   │   │   └── else  # pdays > -1.0000
# │   │   │   │   │   └── Leaf → class = 1  (samples = 4)
# │   │   └── else  # month > may
# │   │   │   ├── if duration <= 74.0000  (Gain = 0.4658)
# │   │   │   │   ├── if month <= nov  (Gain = 0.2472)
# │   │   │   │   │   └── Leaf → class = 0  (samples = 2)
# │   │   │   │   └── else  # month > nov
# │   │   │   │   │   └── Leaf → class = 0  (samples = 10)
# │   │   │   └── else  # duration > 74.0000
# │   │   │   │   ├── if balance <= 730.0000  (Gain = 0.1981)
# │   │   │   │   │   ├── if age <= 42.0000  (Gain = 0.5577)
# │   │   │   │   │   │   └── Leaf → class = 1  (samples = 5)
# │   │   │   │   │   └── else  # age > 42.0000
# │   │   │   │   │   │   └── Leaf → class = 0  (samples = 4)
# │   │   │   │   └── else  # balance > 730.0000
# │   │   │   │   │   └── Leaf → class = 1  (samples = 17)
# └── else  # duration > 383.0000
# │   ├── if duration <= 681.0000  (Gain = 0.0332)
# │   │   ├── if contact <= telephone  (Gain = 0.0365)
# │   │   │   ├── if housing <= no  (Gain = 0.0192)
# │   │   │   │   ├── if pdays <= 56.0000  (Gain = 0.0272)
# │   │   │   │   │   ├── if balance <= 870.0000  (Gain = 0.0152)
# │   │   │   │   │   │   ├── if age <= 60.0000  (Gain = 0.0349)
# │   │   │   │   │   │   │   ├── if month <= jul  (Gain = 0.0252)
# │   │   │   │   │   │   │   │   ├── if month <= dec  (Gain = 0.0472)
# │   │   │   │   │   │   │   │   │   ├── if duration <= 503.0000  (Gain = 0.0809)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 51)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 503.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 55)
# │   │   │   │   │   │   │   │   └── else  # month > dec
# │   │   │   │   │   │   │   │   │   ├── if duration <= 405.0000  (Gain = 0.0633)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 6)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 405.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 96)
# │   │   │   │   │   │   │   └── else  # month > jul
# │   │   │   │   │   │   │   │   ├── if day <= 6.0000  (Gain = 0.0825)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 17)
# │   │   │   │   │   │   │   │   └── else  # day > 6.0000
# │   │   │   │   │   │   │   │   │   ├── if age <= 34.0000  (Gain = 0.0813)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 23)
# │   │   │   │   │   │   │   │   │   └── else  # age > 34.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 25)
# │   │   │   │   │   │   └── else  # age > 60.0000
# │   │   │   │   │   │   │   ├── if marital <= married  (Gain = 0.1442)
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 28)
# │   │   │   │   │   │   │   └── else  # marital > married
# │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 2)
# │   │   │   │   │   └── else  # balance > 870.0000
# │   │   │   │   │   │   ├── if balance <= 1047.0000  (Gain = 0.0225)
# │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 22)
# │   │   │   │   │   │   └── else  # balance > 1047.0000
# │   │   │   │   │   │   │   ├── if balance <= 4831.0000  (Gain = 0.0129)
# │   │   │   │   │   │   │   │   ├── if duration <= 636.0000  (Gain = 0.0346)
# │   │   │   │   │   │   │   │   │   ├── if day <= 13.0000  (Gain = 0.0250)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 65)
# │   │   │   │   │   │   │   │   │   └── else  # day > 13.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 95)
# │   │   │   │   │   │   │   │   └── else  # duration > 636.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 25)
# │   │   │   │   │   │   │   └── else  # balance > 4831.0000
# │   │   │   │   │   │   │   │   ├── if balance <= 5223.0000  (Gain = 0.0705)
# │   │   │   │   │   │   │   │   │   ├── if day <= 23.0000  (Gain = 0.2455)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 10)
# │   │   │   │   │   │   │   │   │   └── else  # day > 23.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 2)
# │   │   │   │   │   │   │   │   └── else  # balance > 5223.0000
# │   │   │   │   │   │   │   │   │   ├── if balance <= 13546.0000  (Gain = 0.0625)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 43)
# │   │   │   │   │   │   │   │   │   └── else  # balance > 13546.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 11)
# │   │   │   │   └── else  # pdays > 56.0000
# │   │   │   │   │   ├── if poutcome <= other  (Gain = 0.0381)
# │   │   │   │   │   │   ├── if pdays <= 345.0000  (Gain = 0.0272)
# │   │   │   │   │   │   │   ├── if pdays <= 195.0000  (Gain = 0.0364)
# │   │   │   │   │   │   │   │   ├── if age <= 33.0000  (Gain = 0.0564)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 24)
# │   │   │   │   │   │   │   │   └── else  # age > 33.0000
# │   │   │   │   │   │   │   │   │   ├── if job <= management  (Gain = 0.0668)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 26)
# │   │   │   │   │   │   │   │   │   └── else  # job > management
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 29)
# │   │   │   │   │   │   │   └── else  # pdays > 195.0000
# │   │   │   │   │   │   │   │   ├── if day <= 6.0000  (Gain = 0.1511)
# │   │   │   │   │   │   │   │   │   ├── if duration <= 545.0000  (Gain = 0.3476)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 5)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 545.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 3)
# │   │   │   │   │   │   │   │   └── else  # day > 6.0000
# │   │   │   │   │   │   │   │   │   ├── if day <= 28.0000  (Gain = 0.3135)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 13)
# │   │   │   │   │   │   │   │   │   └── else  # day > 28.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 6)
# │   │   │   │   │   │   └── else  # pdays > 345.0000
# │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 15)
# │   │   │   │   │   └── else  # poutcome > other
# │   │   │   │   │   │   ├── if age <= 29.0000  (Gain = 0.0568)
# │   │   │   │   │   │   │   ├── if month <= feb  (Gain = 0.2459)
# │   │   │   │   │   │   │   │   ├── if previous <= 2.0000  (Gain = 0.4200)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 3)
# │   │   │   │   │   │   │   │   └── else  # previous > 2.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 2)
# │   │   │   │   │   │   │   └── else  # month > feb
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 8)
# │   │   │   │   │   │   └── else  # age > 29.0000
# │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 101)
# │   │   │   └── else  # housing > no
# │   │   │   │   ├── if duration <= 405.0000  (Gain = 0.0153)
# │   │   │   │   │   ├── if job <= admin.  (Gain = 0.0960)
# │   │   │   │   │   │   └── Leaf → class = 1  (samples = 4)
# │   │   │   │   │   └── else  # job > admin.
# │   │   │   │   │   │   ├── if pdays <= 370.0000  (Gain = 0.0881)
# │   │   │   │   │   │   │   ├── if balance <= 1356.0000  (Gain = 0.0797)
# │   │   │   │   │   │   │   │   ├── if age <= 41.0000  (Gain = 0.1218)
# │   │   │   │   │   │   │   │   │   ├── if day <= 13.0000  (Gain = 0.1834)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 9)
# │   │   │   │   │   │   │   │   │   └── else  # day > 13.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 10)
# │   │   │   │   │   │   │   │   └── else  # age > 41.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 7)
# │   │   │   │   │   │   │   └── else  # balance > 1356.0000
# │   │   │   │   │   │   │   │   ├── if marital <= divorced  (Gain = 0.1427)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 2)
# │   │   │   │   │   │   │   │   └── else  # marital > divorced
# │   │   │   │   │   │   │   │   │   ├── if duration <= 404.0000  (Gain = 0.1992)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 14)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 404.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 2)
# │   │   │   │   │   │   └── else  # pdays > 370.0000
# │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 3)
# │   │   │   │   └── else  # duration > 405.0000
# │   │   │   │   │   ├── if campaign <= 1.0000  (Gain = 0.0135)
# │   │   │   │   │   │   ├── if age <= 28.0000  (Gain = 0.0292)
# │   │   │   │   │   │   │   ├── if balance <= 1977.0000  (Gain = 0.1583)
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 24)
# │   │   │   │   │   │   │   └── else  # balance > 1977.0000
# │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 2)
# │   │   │   │   │   │   └── else  # age > 28.0000
# │   │   │   │   │   │   │   ├── if duration <= 654.0000  (Gain = 0.0221)
# │   │   │   │   │   │   │   │   ├── if marital <= married  (Gain = 0.0273)
# │   │   │   │   │   │   │   │   │   ├── if previous <= 1.0000  (Gain = 0.0560)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 88)
# │   │   │   │   │   │   │   │   │   └── else  # previous > 1.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 25)
# │   │   │   │   │   │   │   │   └── else  # marital > married
# │   │   │   │   │   │   │   │   │   ├── if duration <= 465.0000  (Gain = 0.0836)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 18)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 465.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 45)
# │   │   │   │   │   │   │   └── else  # duration > 654.0000
# │   │   │   │   │   │   │   │   ├── if day <= 3.0000  (Gain = 0.3095)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 1)
# │   │   │   │   │   │   │   │   └── else  # day > 3.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 17)
# │   │   │   │   │   └── else  # campaign > 1.0000
# │   │   │   │   │   │   ├── if balance <= 12857.0000  (Gain = 0.0169)
# │   │   │   │   │   │   │   ├── if balance <= 21.0000  (Gain = 0.0146)
# │   │   │   │   │   │   │   │   ├── if age <= 49.0000  (Gain = 0.1080)
# │   │   │   │   │   │   │   │   │   ├── if duration <= 554.0000  (Gain = 0.0842)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 22)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 554.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 23)
# │   │   │   │   │   │   │   │   └── else  # age > 49.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 5)
# │   │   │   │   │   │   │   └── else  # balance > 21.0000
# │   │   │   │   │   │   │   │   ├── if duration <= 543.0000  (Gain = 0.0288)
# │   │   │   │   │   │   │   │   │   ├── if balance <= 62.0000  (Gain = 0.0439)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 6)
# │   │   │   │   │   │   │   │   │   └── else  # balance > 62.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 103)
# │   │   │   │   │   │   │   │   └── else  # duration > 543.0000
# │   │   │   │   │   │   │   │   │   ├── if duration <= 630.0000  (Gain = 0.0426)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 61)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 630.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 36)
# │   │   │   │   │   │   └── else  # balance > 12857.0000
# │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 3)
# │   │   └── else  # contact > telephone
# │   │   │   ├── if duration <= 457.0000  (Gain = 0.0897)
# │   │   │   │   ├── if month <= feb  (Gain = 0.0638)
# │   │   │   │   │   └── Leaf → class = 1  (samples = 2)
# │   │   │   │   └── else  # month > feb
# │   │   │   │   │   ├── if age <= 30.0000  (Gain = 0.0720)
# │   │   │   │   │   │   ├── if age <= 29.0000  (Gain = 0.2666)
# │   │   │   │   │   │   │   ├── if month <= jun  (Gain = 0.3060)
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 2)
# │   │   │   │   │   │   │   └── else  # month > jun
# │   │   │   │   │   │   │   │   ├── if marital <= divorced  (Gain = 0.2472)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 1)
# │   │   │   │   │   │   │   │   └── else  # marital > divorced
# │   │   │   │   │   │   │   │   │   ├── if education <= primary  (Gain = 0.4395)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 1)
# │   │   │   │   │   │   │   │   │   └── else  # education > primary
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 10)
# │   │   │   │   │   │   └── else  # age > 29.0000
# │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 3)
# │   │   │   │   │   └── else  # age > 30.0000
# │   │   │   │   │   │   ├── if balance <= -411.0000  (Gain = 0.0762)
# │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 3)
# │   │   │   │   │   │   └── else  # balance > -411.0000
# │   │   │   │   │   │   │   ├── if education <= secondary  (Gain = 0.0588)
# │   │   │   │   │   │   │   │   ├── if age <= 38.0000  (Gain = 0.1379)
# │   │   │   │   │   │   │   │   │   ├── if age <= 33.0000  (Gain = 0.2044)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 6)
# │   │   │   │   │   │   │   │   │   └── else  # age > 33.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 10)
# │   │   │   │   │   │   │   │   └── else  # age > 38.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 16)
# │   │   │   │   │   │   │   └── else  # education > secondary
# │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 22)
# │   │   │   └── else  # duration > 457.0000
# │   │   │   │   ├── if duration <= 610.0000  (Gain = 0.0384)
# │   │   │   │   │   ├── if month <= mar  (Gain = 0.0379)
# │   │   │   │   │   │   ├── if housing <= no  (Gain = 0.0869)
# │   │   │   │   │   │   │   ├── if age <= 51.0000  (Gain = 0.2000)
# │   │   │   │   │   │   │   │   ├── if day <= 18.0000  (Gain = 0.1981)
# │   │   │   │   │   │   │   │   │   ├── if balance <= 2892.0000  (Gain = 0.1972)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 16)
# │   │   │   │   │   │   │   │   │   └── else  # balance > 2892.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 2)
# │   │   │   │   │   │   │   │   └── else  # day > 18.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 3)
# │   │   │   │   │   │   │   └── else  # age > 51.0000
# │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 5)
# │   │   │   │   │   │   └── else  # housing > no
# │   │   │   │   │   │   │   ├── if job <= admin.  (Gain = 0.1311)
# │   │   │   │   │   │   │   │   ├── if duration <= 524.0000  (Gain = 0.9852)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 3)
# │   │   │   │   │   │   │   │   └── else  # duration > 524.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 4)
# │   │   │   │   │   │   │   └── else  # job > admin.
# │   │   │   │   │   │   │   │   ├── if education <= tertiary  (Gain = 0.1265)
# │   │   │   │   │   │   │   │   │   ├── if campaign <= 1.0000  (Gain = 0.1589)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 7)
# │   │   │   │   │   │   │   │   │   └── else  # campaign > 1.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 19)
# │   │   │   │   │   │   │   │   └── else  # education > tertiary
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 1)
# │   │   │   │   │   └── else  # month > mar
# │   │   │   │   │   │   ├── if age <= 30.0000  (Gain = 0.0388)
# │   │   │   │   │   │   │   ├── if day <= 27.0000  (Gain = 0.4525)
# │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 13)
# │   │   │   │   │   │   │   └── else  # day > 27.0000
# │   │   │   │   │   │   │   │   ├── if balance <= 668.0000  (Gain = 0.9183)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 4)
# │   │   │   │   │   │   │   │   └── else  # balance > 668.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 2)
# │   │   │   │   │   │   └── else  # age > 30.0000
# │   │   │   │   │   │   │   ├── if balance <= -482.0000  (Gain = 0.0433)
# │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 3)
# │   │   │   │   │   │   │   └── else  # balance > -482.0000
# │   │   │   │   │   │   │   │   ├── if age <= 32.0000  (Gain = 0.0643)
# │   │   │   │   │   │   │   │   │   ├── if marital <= divorced  (Gain = 0.5436)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 1)
# │   │   │   │   │   │   │   │   │   └── else  # marital > divorced
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 7)
# │   │   │   │   │   │   │   │   └── else  # age > 32.0000
# │   │   │   │   │   │   │   │   │   ├── if balance <= -291.0000  (Gain = 0.0651)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 3)
# │   │   │   │   │   │   │   │   │   └── else  # balance > -291.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 53)
# │   │   │   │   └── else  # duration > 610.0000
# │   │   │   │   │   ├── if day <= 28.0000  (Gain = 0.0819)
# │   │   │   │   │   │   ├── if day <= 8.0000  (Gain = 0.1144)
# │   │   │   │   │   │   │   ├── if day <= 5.0000  (Gain = 0.2490)
# │   │   │   │   │   │   │   │   ├── if education <= secondary  (Gain = 0.4464)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 7)
# │   │   │   │   │   │   │   │   └── else  # education > secondary
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 3)
# │   │   │   │   │   │   │   └── else  # day > 5.0000
# │   │   │   │   │   │   │   │   ├── if month <= jun  (Gain = 0.7219)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 1)
# │   │   │   │   │   │   │   │   └── else  # month > jun
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 4)
# │   │   │   │   │   │   └── else  # day > 8.0000
# │   │   │   │   │   │   │   ├── if balance <= 982.0000  (Gain = 0.1721)
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 23)
# │   │   │   │   │   │   │   └── else  # balance > 982.0000
# │   │   │   │   │   │   │   │   ├── if duration <= 651.0000  (Gain = 0.4591)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 3)
# │   │   │   │   │   │   │   │   └── else  # duration > 651.0000
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 3)
# │   │   │   │   │   └── else  # day > 28.0000
# │   │   │   │   │   │   └── Leaf → class = 0  (samples = 4)
# │   └── else  # duration > 681.0000
# │   │   ├── if duration <= 862.0000  (Gain = 0.0041)
# │   │   │   ├── if age <= 35.0000  (Gain = 0.0110)
# │   │   │   │   ├── if previous <= 5.0000  (Gain = 0.0145)
# │   │   │   │   │   ├── if day <= 12.0000  (Gain = 0.0186)
# │   │   │   │   │   │   ├── if pdays <= 342.0000  (Gain = 0.0821)
# │   │   │   │   │   │   │   ├── if duration <= 693.0000  (Gain = 0.0830)
# │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 2)
# │   │   │   │   │   │   │   └── else  # duration > 693.0000
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 64)
# │   │   │   │   │   │   └── else  # pdays > 342.0000
# │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 1)
# │   │   │   │   │   └── else  # day > 12.0000
# │   │   │   │   │   │   ├── if age <= 26.0000  (Gain = 0.0254)
# │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 18)
# │   │   │   │   │   │   └── else  # age > 26.0000
# │   │   │   │   │   │   │   ├── if balance <= 0.0000  (Gain = 0.0205)
# │   │   │   │   │   │   │   │   ├── if duration <= 751.0000  (Gain = 0.2999)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 10)
# │   │   │   │   │   │   │   │   └── else  # duration > 751.0000
# │   │   │   │   │   │   │   │   │   ├── if balance <= -20.0000  (Gain = 0.6549)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 7)
# │   │   │   │   │   │   │   │   │   └── else  # balance > -20.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 5)
# │   │   │   │   │   │   │   └── else  # balance > 0.0000
# │   │   │   │   │   │   │   │   ├── if balance <= 169.0000  (Gain = 0.0308)
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 17)
# │   │   │   │   │   │   │   │   └── else  # balance > 169.0000
# │   │   │   │   │   │   │   │   │   ├── if age <= 34.0000  (Gain = 0.0372)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 70)
# │   │   │   │   │   │   │   │   │   └── else  # age > 34.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 14)
# │   │   │   │   └── else  # previous > 5.0000
# │   │   │   │   │   └── Leaf → class = 0  (samples = 4)
# │   │   │   └── else  # age > 35.0000
# │   │   │   │   ├── if pdays <= -1.0000  (Gain = 0.0196)
# │   │   │   │   │   ├── if job <= student  (Gain = 0.0217)
# │   │   │   │   │   │   ├── if contact <= telephone  (Gain = 0.0184)
# │   │   │   │   │   │   │   ├── if day <= 29.0000  (Gain = 0.0395)
# │   │   │   │   │   │   │   │   ├── if month <= apr  (Gain = 0.0406)
# │   │   │   │   │   │   │   │   │   ├── if age <= 43.0000  (Gain = 0.6100)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 5)
# │   │   │   │   │   │   │   │   │   └── else  # age > 43.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 5)
# │   │   │   │   │   │   │   │   └── else  # month > apr
# │   │   │   │   │   │   │   │   │   ├── if duration <= 856.0000  (Gain = 0.0437)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 105)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 856.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 2)
# │   │   │   │   │   │   │   └── else  # day > 29.0000
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 14)
# │   │   │   │   │   │   └── else  # contact > telephone
# │   │   │   │   │   │   │   ├── if marital <= divorced  (Gain = 0.0924)
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 6)
# │   │   │   │   │   │   │   └── else  # marital > divorced
# │   │   │   │   │   │   │   │   ├── if balance <= 21.0000  (Gain = 0.0724)
# │   │   │   │   │   │   │   │   │   ├── if age <= 58.0000  (Gain = 0.8113)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 6)
# │   │   │   │   │   │   │   │   │   └── else  # age > 58.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 2)
# │   │   │   │   │   │   │   │   └── else  # balance > 21.0000
# │   │   │   │   │   │   │   │   │   ├── if duration <= 695.0000  (Gain = 0.1021)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 5)
# │   │   │   │   │   │   │   │   │   └── else  # duration > 695.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 29)
# │   │   │   │   │   └── else  # job > student
# │   │   │   │   │   │   ├── if education <= tertiary  (Gain = 0.0906)
# │   │   │   │   │   │   │   ├── if campaign <= 3.0000  (Gain = 0.1765)
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 41)
# │   │   │   │   │   │   │   └── else  # campaign > 3.0000
# │   │   │   │   │   │   │   │   ├── if marital <= married  (Gain = 0.2044)
# │   │   │   │   │   │   │   │   │   ├── if marital <= divorced  (Gain = 0.1909)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 1)
# │   │   │   │   │   │   │   │   │   └── else  # marital > divorced
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 5)
# │   │   │   │   │   │   │   │   └── else  # marital > married
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 2)
# │   │   │   │   │   │   └── else  # education > tertiary
# │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 3)
# │   │   │   │   └── else  # pdays > -1.0000
# │   │   │   │   │   ├── if duration <= 759.0000  (Gain = 0.0795)
# │   │   │   │   │   │   └── Leaf → class = 1  (samples = 35)
# │   │   │   │   │   └── else  # duration > 759.0000
# │   │   │   │   │   │   ├── if balance <= 1371.0000  (Gain = 0.1674)
# │   │   │   │   │   │   │   ├── if poutcome <= other  (Gain = 0.1916)
# │   │   │   │   │   │   │   │   ├── if poutcome <= failure  (Gain = 0.4696)
# │   │   │   │   │   │   │   │   │   ├── if age <= 51.0000  (Gain = 0.7219)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 8)
# │   │   │   │   │   │   │   │   │   └── else  # age > 51.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 2)
# │   │   │   │   │   │   │   │   └── else  # poutcome > failure
# │   │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 4)
# │   │   │   │   │   │   │   └── else  # poutcome > other
# │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 6)
# │   │   │   │   │   │   └── else  # balance > 1371.0000
# │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 19)
# │   │   └── else  # duration > 862.0000
# │   │   │   ├── if duration <= 877.0000  (Gain = 0.0056)
# │   │   │   │   └── Leaf → class = 1  (samples = 30)
# │   │   │   └── else  # duration > 877.0000
# │   │   │   │   ├── if balance <= -3.0000  (Gain = 0.0056)
# │   │   │   │   │   ├── if day <= 6.0000  (Gain = 0.0569)
# │   │   │   │   │   │   ├── if balance <= -414.0000  (Gain = 0.5917)
# │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 1)
# │   │   │   │   │   │   └── else  # balance > -414.0000
# │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 6)
# │   │   │   │   │   └── else  # day > 6.0000
# │   │   │   │   │   │   └── Leaf → class = 1  (samples = 46)
# │   │   │   │   └── else  # balance > -3.0000
# │   │   │   │   │   ├── if campaign <= 7.0000  (Gain = 0.0054)
# │   │   │   │   │   │   ├── if duration <= 878.0000  (Gain = 0.0043)
# │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 1)
# │   │   │   │   │   │   └── else  # duration > 878.0000
# │   │   │   │   │   │   │   ├── if age <= 84.0000  (Gain = 0.0043)
# │   │   │   │   │   │   │   │   ├── if day <= 2.0000  (Gain = 0.0041)
# │   │   │   │   │   │   │   │   │   ├── if age <= 42.0000  (Gain = 0.2653)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 13)
# │   │   │   │   │   │   │   │   │   └── else  # age > 42.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 10)
# │   │   │   │   │   │   │   │   └── else  # day > 2.0000
# │   │   │   │   │   │   │   │   │   ├── if pdays <= 315.0000  (Gain = 0.0037)
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 674)
# │   │   │   │   │   │   │   │   │   └── else  # pdays > 315.0000
# │   │   │   │   │   │   │   │   │   │   └── Leaf → class = 1  (samples = 32)
# │   │   │   │   │   │   │   └── else  # age > 84.0000
# │   │   │   │   │   │   │   │   └── Leaf → class = 0  (samples = 1)
# │   │   │   │   │   └── else  # campaign > 7.0000
# │   │   │   │   │   │   └── Leaf → class = 1  (samples = 24)

# %% [markdown]
# ## Using pre_defined library's functions

# %%
from sklearn.tree import DecisionTreeClassifier
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, NUMERICAL),
        ('cat', categorical_transformer, CATEGORICAL)
    ]
)
DT_model = DecisionTreeClassifier(random_state=random_state)

pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', DT_model)
])

pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['campaign', 'pdays', 'age',
#                                                    'balance', 'previous',
#                                                    'duration', 'day']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['loan', 'marital', 'contact',
#                                                    'default', 'education',
#                                                    'job', 'poutcome', 'month',
#                                                    'housing'])])),
#                 ('classifier', DecisionTreeClassifier(random_state=999))])

# %%
y_pred = pipeline.predict(X_test)
print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#           no     0.8120    0.8030    0.8075      1183
#          yes     0.7808    0.7905    0.7856      1050
#
#     accuracy                         0.7971      2233
#    macro avg     0.7964    0.7968    0.7965      2233
# weighted avg     0.7973    0.7971    0.7972      2233

# %% [markdown]
# ## Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
RF_model = RandomForestClassifier(
    n_estimators=200,       # number of trees
    criterion='entropy',   
    max_depth=None,         
    random_state=random_state
)

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, NUMERICAL),
        ('cat', categorical_transformer, CATEGORICAL)
    ]
)

pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', RF_model)
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['campaign', 'pdays', 'age',
#                                                    'balance', 'previous',
#                                                    'duration', 'day']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['loan', 'marital', 'contact',
#                                                    'default', 'education',
#                                                    'job', 'poutcome', 'month',
#                                                    'housing'])])),
#                 ('classifier',
#                  RandomForestClassifier(criterion='entropy', n_estimators=200,
#                                         random_state=999))])

# %%
y_pred = pipeline.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.89      0.83      0.86      1183
#          yes       0.83      0.89      0.86      1050
#
#     accuracy                           0.86      2233
#    macro avg       0.86      0.86      0.86      2233
# weighted avg       0.86      0.86      0.86      2233
#
# [[987 196]
#  [117 933]]

# %%
import pandas as pd

rf_feature_importance = pipeline.named_steps['classifier'].feature_importances_

# ویژگی‌های عددی بعد از OneHotEncoder ممکن است زیاد شوند:
feature_names = pipeline.named_steps['preprocessor'].get_feature_names_out()

importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': rf_feature_importance
}).sort_values(by='Importance', ascending=False)

print(importance_df.head(10))
# Out:
#                   Feature  Importance
# 5           num__duration    0.304926
# 3            num__balance    0.083497
# 2                num__age    0.077073
# 6                num__day    0.071661
# 0           num__campaign    0.038732
# 1              num__pdays    0.032759
# 35  cat__poutcome_success    0.029970
# 14   cat__contact_unknown    0.020877
# 4           num__previous    0.019495
# 50       cat__housing_yes    0.016393
